# %% [markdown]
# <p style="align: center;"><img src="https://static.tildacdn.com/tild6636-3531-4239-b465-376364646465/Deep_Learning_School.png", width=300, height=300></p>
#
# <h3 style="text-align: center;"><b>Физтех-Школа Прикладной математики и информатики (ФПМИ) МФТИ</b></h3>

# %% [markdown]
# ---

# %% [markdown]
# <h2 style="text-align: center;"><b>Один нейрон на PyTorch</b></h3>

# %% [markdown]
# В этом ноутбуке мы научимся писать свои нейросети на фреймворке PyTorch, конкретно - рассмотрим, как написать свой нейрон с разными функциями потерь и рассмотрим его работу на конкретных датасетах.

# %% [markdown]
# <h3 style="text-align: center;"><b>Компоненты нейросети</b></h3>

# %% [markdown]
# Здесь самое время напомнить о том, какие вещи играют принципиальную роль в построении любой ***нейронной сети*** (все их мы задаём *руками*, самостоятельно):
#
# - непосредственно, сама **архитектура** нейросети (сюда входят типы функций активации у каждого нейрона);
# - начальная **инициализация** весов каждого слоя;
# - метод **оптимизации** нейросети (сюда ещё входит метод изменения `learning_rate`);
# - размер **батчей** (`batch_size`);
# - количество итераций обучения (`num_epochs`);
# - **функция потерь** (`loss`);
# - тип **регуляризации** нейросети (для каждого слоя можно свой);
#
# То, что связано с ***данными и задачей***:
# - само **качество** выборки (непротиворечивость, чистота, корректность постановки задачи);
# - **размер** выборки;

# %% [markdown]
# <h3 style="text-align: center;"><b>Один нейрон на PyTorch</b></h3>

# %% [markdown]
# Данные пока что возьмём как и прежде - "яблоки и груши":

# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
data = pd.read_csv("./data/apples_pears.csv")

# %%
plt.figure(figsize=(10, 8))
plt.scatter(data.iloc[:, 0], data.iloc[:, 1], c=data['target'], cmap='rainbow')
plt.title('Яблоки и груши', fontsize=15)
plt.xlabel('симметричность', fontsize=14)
plt.ylabel('желтизна', fontsize=14)
plt.show();

# %%
X = data.iloc[:,:2].values  # матрица объекты-признаки
y = data['target'].values.reshape((-1, 1))  # классы (столбец из нулей и единиц)

# %% [markdown]
# В модуле torch.nn лежат все необходимые вещи для конструирования нейронок, а в модуле torch.optim лежат все необходимые вещи для выбора метода оптимизации нейросети:

# %%
import torch
from torch.nn import Linear, Sigmoid

# %% [markdown]
# Есть **два пути объявления нейросетей** в PyTorch:
# - ***функциональный (`Functional`);***
# - ***последовательный (`Sequential`);  ***
#
# Рассмотрим второй путь (он чуть более user-friendly), к первому потом ещё вернёмся, и построим таким способом один нейрон (точно такой же, который мы реализовывали раньше с помощью Numpy):

# %%
num_features = X.shape[1]

neuron = torch.nn.Sequential(
    Linear(num_features, out_features=1),
    Sigmoid()
)

# %%
neuron
# Out:
# Sequential(
#   (0): Linear(in_features=2, out_features=1, bias=True)
#   (1): Sigmoid()
# )

# %% [markdown]
# Пока что мы просто создали объект класса `Sequential`, который состоит из одного линейного слоя размерности (num_features, 1) и последующего применения сигмоиды. Но уже сейчас его можно применить к объекту (тензору), просто веса в начале инициализирутся случайно и при forward_pass'е мы получим какой-то ответ пока что необученного нейрона:

# %%
neuron(torch.autograd.Variable(torch.FloatTensor([1, 1])))
# Out:
# tensor([0.3084], grad_fn=<SigmoidBackward>)

# %% [markdown]
# Предскажем ещё необученным нейроном:

# %%
proba_pred = neuron(torch.autograd.Variable(torch.FloatTensor(X)))
y_pred = proba_pred > 0.5
y_pred = y_pred.data.numpy().reshape(-1)

plt.figure(figsize=(10, 8))
plt.scatter(data.iloc[:, 0], data.iloc[:, 1], c=y_pred, cmap='spring')
plt.title('Яблоки и груши', fontsize=15)
plt.xlabel('симметричность', fontsize=14)
plt.ylabel('желтизна', fontsize=14)
plt.show();

# %% [markdown]
# Как и ожидалось, ничего полезного. Давайте научим нейрон отличать груши от яблок по их симметричности и желтизне!

# %% [markdown]
# Обернём данные в `torch.Tensor`'ы, а тензоры в `torch.Variable`'ы, чтобы можно было вычислять градиенты по весам:

# %%
X = torch.autograd.Variable(torch.FloatTensor(X))
y = torch.autograd.Variable(torch.FloatTensor(y))

# %% [markdown]
# Код обучения одного нейрона на PyTorch:

# %%
# квадратичная функция потерь (можно сделать другую)
loss_fn = torch.nn.MSELoss(size_average=False)

# шаг градиентного спуска (точнее -- метода оптимизации)
learning_rate = 0.001  # == 1e-3
# сам метод оптимизации нейросети (обычно лучше всего по-умолчанию рабоатет Adam)
optimizer = torch.optim.SGD(neuron.parameters(), lr=learning_rate)
# итерируемся num_epochs раз, здесь 500
for t in range(500):
    # foward_pass() -- применение нейросети (этот шаг ещё называют inference)
    y_pred = neuron(X)

    # выведем loss
    loss = loss_fn(y_pred, y)
    print('{} {}'.format(t, loss.data))

    # ВСЕГДА обнуляйте градиенты перед backard_pass'ом
    # подробнее: читайте документацию PyTorch
    optimizer.zero_grad()

    # backward_pass() -- вычисляем градиенты loss'а по параметрам (весам) нейросети
    # ВНИМАНИЕ! На это шаге мы только вычисляем градиенты, но ещё не обновляем веса
    loss.backward()

    # А вот тут уже обновляем
    optimizer.step()
# Out:
# C:\Users\yushanov\Anaconda3\lib\site-packages\torch\nn\_reduction.py:49: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# 0 290.73040771484375
# 1 272.0622253417969
# 2 257.20074462890625
# 3 245.70755004882812
# 4 236.83865356445312
# 5 229.85679626464844
# 6 224.17213439941406
# 7 219.36209106445312
# 8 215.14151000976562
# 9 211.32406616210938
# 10 207.79005432128906
# 11 204.4631805419922
# 12 201.29498291015625
# 13 198.25466918945312
# 14 195.322509765625
# 15 192.4857940673828
# 16 189.736083984375
# 17 187.06765747070312
# 18 184.4763641357422
# 19 181.95907592773438
# 20 179.51321411132812
# 21 177.1365509033203
# 22 174.82704162597656
# 23 172.58273315429688
# 24 170.40176391601562
# 25 168.2822723388672
# 26 166.22242736816406
# 27 164.22044372558594
# 28 162.2745361328125
# 29 160.3829345703125
# 30 158.54393005371094
# 31 156.75579833984375
# 32 155.01687622070312
# 33 153.32554626464844
# 34 151.6802215576172
# 35 150.079345703125
# 36 148.5214080810547
# 37 147.00497436523438
# 38 145.5286102294922
# 39 144.09095764160156
# 40 142.69068908691406
# 41 141.32650756835938
# 42 139.99720764160156
# 43 138.7015838623047
# 44 137.4384765625
# 45 136.206787109375
# 46 135.0054473876953
# 47 133.83343505859375
# 48 132.68975830078125
# 49 131.5734405517578
# 50 130.48361206054688
# 51 129.4193572998047
# 52 128.3798370361328
# 53 127.36422729492188
# 54 126.37176513671875
# 55 125.40167999267578
# 56 124.45325469970703
# 57 123.52578735351562
# 58 122.61862182617188
# 59 121.73109436035156
# 60 120.86259460449219
# 61 120.01252746582031
# 62 119.18031311035156
# 63 118.36540985107422
# 64 117.56726837158203
# 65 116.785400390625
# 66 116.0193099975586
# 67 115.26851654052734
# 68 114.53256225585938
# 69 113.81101989746094
# 70 113.10345458984375
# 71 112.40946960449219
# 72 111.72867584228516
# 73 111.06068420410156
# 74 110.40513610839844
# 75 109.76168060302734
# 76 109.1299819946289
# 77 108.50970458984375
# 78 107.90054321289062
# 79 107.30219268798828
# 80 106.71435546875
# 81 106.13675689697266
# 82 105.5691146850586
# 83 105.01116943359375
# 84 104.4626693725586
# 85 103.9233627319336
# 86 103.39301300048828
# 87 102.87139129638672
# 88 102.35828399658203
# 89 101.85345458984375
# 90 101.35671997070312
# 91 100.86787414550781
# 92 100.38671112060547
# 93 99.91304779052734
# 94 99.44670104980469
# 95 98.98750305175781
# 96 98.53527069091797
# 97 98.08984375
# 98 97.65106201171875
# 99 97.21878051757812
# 100 96.79283142089844
# 101 96.37307739257812
# 102 95.9593734741211
# 103 95.55158996582031
# 104 95.14958190917969
# 105 94.75322723388672
# 106 94.3624038696289
# 107 93.97698211669922
# 108 93.59685516357422
# 109 93.22189331054688
# 110 92.85199737548828
# 111 92.48705291748047
# 112 92.12696075439453
# 113 91.77161407470703
# 114 91.42091369628906
# 115 91.07476043701172
# 116 90.73307037353516
# 117 90.39573669433594
# 118 90.06268310546875
# 119 89.73381805419922
# 120 89.40906524658203
# 121 89.08833312988281
# 122 88.77154541015625
# 123 88.45862579345703
# 124 88.14949035644531
# 125 87.84408569335938
# 126 87.54231262207031
# 127 87.24412536621094
# 128 86.94944763183594
# 129 86.65821838378906
# 130 86.370361328125
# 131 86.0858154296875
# 132 85.80452728271484
# 133 85.52643585205078
# 134 85.25148010253906
# 135 84.97959899902344
# 136 84.71074676513672
# 137 84.44486236572266
# 138 84.18189239501953
# 139 83.92179107666016
# 140 83.66450500488281
# 141 83.40998077392578
# 142 83.15817260742188
# 143 82.9090347290039
# 144 82.66252899169922
# 145 82.41859436035156
# 146 82.17720794677734
# 147 81.93830871582031
# 148 81.70186614990234
# 149 81.46783447265625
# 150 81.23616790771484
# 151 81.00684356689453
# 152 80.7798080444336
# 153 80.5550308227539
# 154 80.33247375488281
# 155 80.11210632324219
# 156 79.89389038085938
# 157 79.67778015136719
# 158 79.46376037597656
# 159 79.25179290771484
# 160 79.04183959960938
# 161 78.83387756347656
# 162 78.62787628173828
# 163 78.42378997802734
# 164 78.22161102294922
# 165 78.02130126953125
# 166 77.82282257080078
# 167 77.62616729736328
# 168 77.43128967285156
# 169 77.23817443847656
# 170 77.04679107666016
# 171 76.85711669921875
# 172 76.66912841796875
# 173 76.48279571533203
# 174 76.29810333251953
# 175 76.1150131225586
# 176 75.93351745605469
# 177 75.75359344482422
# 178 75.57520294189453
# 179 75.3983383178711
# 180 75.22297668457031
# 181 75.0490951538086
# 182 74.87667083740234
# 183 74.7056884765625
# 184 74.53612518310547
# 185 74.36796569824219
# 186 74.20117950439453
# 187 74.0357666015625
# 188 73.87169647216797
# 189 73.70894622802734
# 190 73.5475082397461
# 191 73.38735961914062
# 192 73.2284927368164
# 193 73.07088470458984
# 194 72.91451263427734
# 195 72.75936889648438
# 196 72.60543060302734
# 197 72.45269775390625
# 198 72.30113983154297
# 199 72.15074157714844
# 200 72.00149536132812
# 201 71.85338592529297
# 202 71.70639038085938
# 203 71.56050872802734
# 204 71.41571807861328
# 205 71.27200317382812
# 206 71.12936401367188
# 207 70.98777770996094
# 208 70.84722137451172
# 209 70.70770263671875
# 210 70.5691909790039
# 211 70.43168640136719
# 212 70.29517364501953
# 213 70.1596450805664
# 214 70.02507781982422
# 215 69.89146423339844
# 216 69.75880432128906
# 217 69.6270751953125
# 218 69.49627685546875
# 219 69.36637878417969
# 220 69.23739624023438
# 221 69.10929870605469
# 222 68.9820785522461
# 223 68.8557357788086
# 224 68.73025512695312
# 225 68.60562133789062
# 226 68.4818344116211
# 227 68.35887908935547
# 228 68.23674774169922
# 229 68.11543273925781
# 230 67.99492645263672
# 231 67.87521362304688
# 232 67.75627899169922
# 233 67.63813781738281
# 234 67.52075958251953
# 235 67.40414428710938
# 236 67.28829193115234
# 237 67.17317962646484
# 238 67.05879974365234
# 239 66.94515991210938
# 240 66.83223724365234
# 241 66.72003173828125
# 242 66.60853576660156
# 243 66.49773406982422
# 244 66.38763427734375
# 245 66.27821350097656
# 246 66.16947174072266
# 247 66.06140899658203
# 248 65.9540023803711
# 249 65.84725952148438
# 250 65.74116516113281
# 251 65.63571166992188
# 252 65.5309066772461
# 253 65.42671966552734
# 254 65.32317352294922
# 255 65.2202377319336
# 256 65.11791229248047
# 257 65.01619720458984
# 258 64.91508483886719
# 259 64.81456756591797
# 260 64.71463775634766
# 261 64.61528778076172
# 262 64.51651763916016
# 263 64.41832733154297
# 264 64.32069396972656
# 265 64.22362518310547
# 266 64.12711334228516
# 267 64.0311508178711
# 268 63.93573760986328
# 269 63.840858459472656
# 270 63.746517181396484
# 271 63.652706146240234
# 272 63.559417724609375
# 273 63.46665573120117
# 274 63.37440490722656
# 275 63.28266143798828
# 276 63.191429138183594
# 277 63.10069274902344
# 278 63.01045608520508
# 279 62.92071533203125
# 280 62.83145523071289
# 281 62.74268341064453
# 282 62.654388427734375
# 283 62.566566467285156
# 284 62.479217529296875
# 285 62.392333984375
# 286 62.305912017822266
# 287 62.219947814941406
# 288 62.134437561035156
# 289 62.04937744140625
# 290 61.964759826660156
# 291 61.88058853149414
# 292 61.79685592651367
# 293 61.71355438232422
# 294 61.63068389892578
# 295 61.548240661621094
# 296 61.46622085571289
# 297 61.384620666503906
# 298 61.303436279296875
# 299 61.222660064697266
# 300 61.14229965209961
# 301 61.062339782714844
# 302 60.982784271240234
# 303 60.90362548828125
# 304 60.82486343383789
# 305 60.746490478515625
# 306 60.66850662231445
# 307 60.590911865234375
# 308 60.513694763183594
# 309 60.436859130859375
# 310 60.36039733886719
# 311 60.2843132019043
# 312 60.208595275878906
# 313 60.13324737548828
# 314 60.058258056640625
# 315 59.98363494873047
# 316 59.909366607666016
# 317 59.835453033447266
# 318 59.76189422607422
# 319 59.688682556152344
# 320 59.61581802368164
# 321 59.543296813964844
# 322 59.47111892700195
# 323 59.3992805480957
# 324 59.32777404785156
# 325 59.2566032409668
# 326 59.18576431274414
# 327 59.11524963378906
# 328 59.04506301879883
# 329 58.97520065307617
# 330 58.90565490722656
# 331 58.83643341064453
# 332 58.767520904541016
# 333 58.69892501831055
# 334 58.630638122558594
# 335 58.562660217285156
# 336 58.494991302490234
# 337 58.42761993408203
# 338 58.36055374145508
# 339 58.293785095214844
# 340 58.227317810058594
# 341 58.16114044189453
# 342 58.09525680541992
# 343 58.029666900634766
# 344 57.96436309814453
# 345 57.89934158325195
# 346 57.8346061706543
# 347 57.7701530456543
# 348 57.70598220825195
# 349 57.64208984375
# 350 57.578468322753906
# 351 57.51512145996094
# 352 57.45204544067383
# 353 57.389244079589844
# 354 57.32670974731445
# 355 57.26443862915039
# 356 57.20243453979492
# 357 57.140689849853516
# 358 57.07920455932617
# 359 57.01797866821289
# 360 56.95701217651367
# 361 56.896297454833984
# 362 56.835838317871094
# 363 56.775630950927734
# 364 56.71567153930664
# 365 56.65596008300781
# 366 56.596492767333984
# 367 56.537269592285156
# 368 56.47829055786133
# 369 56.419551849365234
# 370 56.36104965209961
# 371 56.30278778076172
# 372 56.2447624206543
# 373 56.18696975708008
# 374 56.12941360473633
# 375 56.072086334228516
# 376 56.01498794555664
# 377 55.95812225341797
# 378 55.9014778137207
# 379 55.845062255859375
# 380 55.78886413574219
# 381 55.73289489746094
# 382 55.67714309692383
# 383 55.62160873413086
# 384 55.5662956237793
# 385 55.511199951171875
# 386 55.45631790161133
# 387 55.401649475097656
# 388 55.347190856933594
# 389 55.29294204711914
# 390 55.23890686035156
# 391 55.18507766723633
# 392 55.13145446777344
# 393 55.07803726196289
# 394 55.02482223510742
# 395 54.9718132019043
# 396 54.919002532958984
# 397 54.866390228271484
# 398 54.8139762878418
# 399 54.76176452636719
# 400 54.70974349975586
# 401 54.657920837402344
# 402 54.60628890991211
# 403 54.55485153198242
# 404 54.503604888916016
# 405 54.45254898071289
# 406 54.40167999267578
# 407 54.35100173950195
# 408 54.30051040649414
# 409 54.25019836425781
# 410 54.200077056884766
# 411 54.1501350402832
# 412 54.100379943847656
# 413 54.050804138183594
# 414 54.00140380859375
# 415 53.952186584472656
# 416 53.90314483642578
# 417 53.854278564453125
# 418 53.80559158325195
# 419 53.75707244873047
# 420 53.70873260498047
# 421 53.66056442260742
# 422 53.61256408691406
# 423 53.564735412597656
# 424 53.51707458496094
# 425 53.469581604003906
# 426 53.42226028442383
# 427 53.375099182128906
# 428 53.32810592651367
# 429 53.281280517578125
# 430 53.23461151123047
# 431 53.188106536865234
# 432 53.14176559448242
# 433 53.0955810546875
# 434 53.049560546875
# 435 53.00369644165039
# 436 52.95798873901367
# 437 52.912437438964844
# 438 52.867042541503906
# 439 52.82180404663086
# 440 52.77671813964844
# 441 52.73178482055664
# 442 52.68700408935547
# 443 52.642372131347656
# 444 52.597896575927734
# 445 52.553565979003906
# 446 52.50938415527344
# 447 52.46535110473633
# 448 52.42146682739258
# 449 52.37772750854492
# 450 52.334129333496094
# 451 52.290679931640625
# 452 52.247371673583984
# 453 52.20420837402344
# 454 52.16118621826172
# 455 52.11830520629883
# 456 52.07556915283203
# 457 52.03296661376953
# 458 51.990509033203125
# 459 51.948184967041016
# 460 51.906002044677734
# 461 51.86395263671875
# 462 51.82204055786133
# 463 51.7802619934082
# 464 51.73862075805664
# 465 51.697113037109375
# 466 51.655738830566406
# 467 51.61449432373047
# 468 51.57338333129883
# 469 51.53240203857422
# 470 51.491546630859375
# 471 51.45082473754883
# 472 51.41023254394531
# 473 51.36977005004883
# 474 51.32943344116211
# 475 51.289222717285156
# 476 51.24913787841797
# 477 51.20917892456055
# 478 51.169342041015625
# 479 51.12963104248047
# 480 51.09004211425781
# 481 51.05057907104492
# 482 51.01123809814453
# 483 50.97201919555664
# 484 50.932918548583984
# 485 50.89393997192383
# 486 50.85507583618164
# 487 50.81633758544922
# 488 50.7777099609375
# 489 50.73920440673828
# 490 50.70081329345703
# 491 50.66254425048828
# 492 50.624385833740234
# 493 50.58634567260742
# 494 50.54841995239258
# 495 50.51060485839844
# 496 50.47290802001953
# 497 50.43531799316406
# 498 50.39784622192383
# 499 50.36048126220703

# %% [markdown]
# Обучили. Предскажем теперь:

# %%
proba_pred = neuron(X)
y_pred = proba_pred > 0.5
y_pred = y_pred.data.numpy().reshape(-1)

plt.figure(figsize=(10, 8))
plt.scatter(data.iloc[:, 0], data.iloc[:, 1], c=y_pred, cmap='spring')
plt.title('Яблоки и груши', fontsize=15)
plt.xlabel('симметричность', fontsize=14)
plt.ylabel('желтизна', fontsize=14)
plt.show();

# %% [markdown]
# ---

# %% [markdown]
# ### Задача 1

# %% [markdown]
# 1. Как видно по рисунку - качество не идеальное (даже перцептрон на нумпае лучше :). Добейтесь идеального качества (или очень близкого к идеальному), путём изменения `learning_rate` и количества итераций (возможно, ещё функции потерь и функции активации);
# 2. Используйте функцию потерь `torch.nn.NLLLoss()` (== LogLoss) или `torch.nn.CrossEntropy()`, сделайте вывод о работе нейрона.

# %%
# Ваш код здесь (можно создавать много ячеек)
loss_fn = torch.nn.CrossEntropyLoss()

learning_rate = 0.2  # == 1e-3
optimizer = torch.optim.SGD(neuron.parameters(), lr=learning_rate)
for t in range(500):
    y_pred = neuron(X)
    loss = loss_fn(y_pred, y)
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
print('loss: {}'.format(loss.data))
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-46-247f8427d283> in <module>()
#       6 for t in range(500):
#       7     y_pred = neuron(X)
# ----> 8     loss = loss_fn(y_pred, y)
#       9     optimizer.zero_grad()
#      10     loss.backward()
#
# ~\Anaconda3\lib\site-packages\torch\nn\modules\module.py in __call__(self, *input, **kwargs)
#     487             result = self._slow_forward(*input, **kwargs)
#     488         else:
# --> 489             result = self.forward(*input, **kwargs)
#     490         for hook in self._forward_hooks.values():
#     491             hook_result = hook(self, input, result)
#
# ~\Anaconda3\lib\site-packages\torch\nn\modules\loss.py in forward(self, input, target)
#     902     def forward(self, input, target):
#     903         return F.cross_entropy(input, target, weight=self.weight,
# --> 904                                ignore_index=self.ignore_index, reduction=self.reduction)
#     905
#     906
#
# ~\Anaconda3\lib\site-packages\torch\nn\functional.py in cross_entropy(input, target, weight, size_average, ignore_index, reduce, reduction)
#    1968     if size_average is not None or reduce is not None:
#    1969         reduction = _Reduction.legacy_get_string(size_average, reduce)
# -> 1970     return nll_loss(log_softmax(input, 1), target, weight, None, ignore_index, None, reduction)
#    1971
#    1972
#
# ~\Anaconda3\lib\site-packages\torch\nn\functional.py in nll_loss(input, target, weight, size_average, ignore_index, reduce, reduction)
#    1788                          .format(input.size(0), target.size(0)))
#    1789     if dim == 2:
# -> 1790         ret = torch._C._nn.nll_loss(input, target, weight, _Reduction.get_enum(reduction), ignore_index)
#    1791     elif dim == 4:
#    1792         ret = torch._C._nn.nll_loss2d(input, target, weight, _Reduction.get_enum(reduction), ignore_index)
#
# RuntimeError: Expected object of scalar type Long but got scalar type Float for argument #2 'target'

# %%
#proba_pred = neuron(X)
#y_pred = proba_pred > 0.5
y_pred = y.data.numpy().reshape(-1)

plt.figure(figsize=(10, 8))
plt.scatter(data.iloc[:, 0], data.iloc[:, 1], c=y_pred, cmap='spring')
plt.title('Яблоки и груши', fontsize=15)
plt.xlabel('симметричность', fontsize=14)
plt.ylabel('желтизна', fontsize=14)
plt.show();

# %% [markdown]
# ---

# %% [markdown]
# Круто. Нейрон работет, отличает яблоки от груш (Вы ведь этого добились, правда?). Но так ли он силён? Давайте попробуем более сложную выборку, которая уже не разделяется линейно:

# %%
# код для генерации взят из Стэнфордсокго курса:
# http://cs231n.github.io/neural-networks-case-study/#linear

N = 100
D = 2
K = 3
X = np.zeros((N * K, D))
y = np.zeros(N * K, dtype='uint8')

for j in range(K):
    ix = range(N * j,N * (j + 1))
    r = np.linspace(0.0, 1, N)
    t = np.linspace(j * 4, (j + 1) * 4,N) + np.random.randn(N) * 0.2 # theta
    X[ix] = np.c_[r * np.sin(t), r * np.cos(t)]
    y[ix] = j

plt.figure(figsize=(10, 8))
plt.scatter(X[:, 0], X[:, 1], c=y, s=40, cmap=plt.cm.rainbow)
plt.title('Игрушка дьявола', fontsize=15)
plt.xlabel('$x$', fontsize=14)
plt.ylabel('$y$', fontsize=14)
plt.show();

# %% [markdown]
# Данные в Variable() (без этого градиенты не посчитать):

# %%
X = torch.autograd.Variable(torch.FloatTensor(X))
y = torch.autograd.Variable(torch.LongTensor(y.astype(np.int64)))

# %%
print(X.data.shape, y.data.shape)
# Out:
# torch.Size([300, 2]) torch.Size([300])

# %% [markdown]
# В атаку, наш славный нейрон с сигмоидой (точнее в данном случае это уже 3 нейрона с софтмаксом):

# %%
# пример взят из официального туториала: 
# https://pytorch.org/tutorials/beginner/pytorch_with_examples.html

# N - размер батча (batch_size, нужно для метода оптимизации); 
# D_in - размерность входа (количество признаков у объекта);
# D_out - размерность выходного слоя (суть - количество классов)
N, D_in, D_out = 64, 2, 3

neuron = torch.nn.Sequential(
    torch.nn.Linear(D_in, D_out),
)

loss_fn = torch.nn.CrossEntropyLoss(size_average=False)

learning_rate = 1e-4
optimizer = torch.optim.SGD(neuron.parameters(), lr=learning_rate)
for t in range(500):
    # forward
    y_pred = neuron(X)

    # loss
    loss = loss_fn(y_pred, y)
    print('{} {}'.format(t, loss.data))

    # ЗАНУЛЯЕМ!
    optimizer.zero_grad()

    # backward
    loss.backward()

    # ОБНОВЛЯЕМ! 
    optimizer.step()
# Out:
# 0
#  357.2256
# [torch.FloatTensor of size 1]
#
# 1
#  356.7443
# [torch.FloatTensor of size 1]
#
# 2
#  356.2664
# [torch.FloatTensor of size 1]
#
# 3
#  355.7916
# [torch.FloatTensor of size 1]
#
# 4
#  355.3206
# [torch.FloatTensor of size 1]
#
# 5
#  354.8528
# [torch.FloatTensor of size 1]
#
# 6
#  354.3882
# [torch.FloatTensor of size 1]
#
# 7
#  353.9270
# [torch.FloatTensor of size 1]
#
# 8
#  353.4688
# [torch.FloatTensor of size 1]
#
# 9
#  353.0139
# [torch.FloatTensor of size 1]
#
# 10
#  352.5622
# [torch.FloatTensor of size 1]
#
# 11
#  352.1138
# [torch.FloatTensor of size 1]
#
# 12
#  351.6683
# [torch.FloatTensor of size 1]
#
# 13
#  351.2257
# [torch.FloatTensor of size 1]
#
# 14
#  350.7863
# [torch.FloatTensor of size 1]
#
# 15
#  350.3502
# [torch.FloatTensor of size 1]
#
# 16
#  349.9168
# [torch.FloatTensor of size 1]
#
# 17
#  349.4862
# [torch.FloatTensor of size 1]
#
# 18
#  349.0590
# [torch.FloatTensor of size 1]
#
# 19
#  348.6344
# [torch.FloatTensor of size 1]
#
# 20
#  348.2126
# [torch.FloatTensor of size 1]
#
# 21
#  347.7941
# [torch.FloatTensor of size 1]
#
# 22
#  347.3780
# [torch.FloatTensor of size 1]
#
# 23
#  346.9645
# [torch.FloatTensor of size 1]
#
# 24
#  346.5542
# [torch.FloatTensor of size 1]
#
# 25
#  346.1465
# [torch.FloatTensor of size 1]
#
# 26
#  345.7413
# [torch.FloatTensor of size 1]
#
# 27
#  345.3390
# [torch.FloatTensor of size 1]
#
# 28
#  344.9392
# [torch.FloatTensor of size 1]
#
# 29
#  344.5422
# [torch.FloatTensor of size 1]
#
# 30
#  344.1476
# [torch.FloatTensor of size 1]
#
# 31
#  343.7557
# [torch.FloatTensor of size 1]
#
# 32
#  343.3663
# [torch.FloatTensor of size 1]
#
# 33
#  342.9796
# [torch.FloatTensor of size 1]
#
# 34
#  342.5953
# [torch.FloatTensor of size 1]
#
# 35
#  342.2132
# [torch.FloatTensor of size 1]
#
# 36
#  341.8338
# [torch.FloatTensor of size 1]
#
# 37
#  341.4567
# [torch.FloatTensor of size 1]
#
# 38
#  341.0822
# [torch.FloatTensor of size 1]
#
# 39
#  340.7100
# [torch.FloatTensor of size 1]
#
# 40
#  340.3402
# [torch.FloatTensor of size 1]
#
# 41
#  339.9725
# [torch.FloatTensor of size 1]
#
# 42
#  339.6072
# [torch.FloatTensor of size 1]
#
# 43
#  339.2443
# [torch.FloatTensor of size 1]
#
# 44
#  338.8836
# [torch.FloatTensor of size 1]
#
# 45
#  338.5251
# [torch.FloatTensor of size 1]
#
# 46
#  338.1688
# [torch.FloatTensor of size 1]
#
# 47
#  337.8148
# [torch.FloatTensor of size 1]
#
# 48
#  337.4630
# [torch.FloatTensor of size 1]
#
# 49
#  337.1132
# [torch.FloatTensor of size 1]
#
# 50
#  336.7656
# [torch.FloatTensor of size 1]
#
# 51
#  336.4200
# [torch.FloatTensor of size 1]
#
# 52
#  336.0765
# [torch.FloatTensor of size 1]
#
# 53
#  335.7351
# [torch.FloatTensor of size 1]
#
# 54
#  335.3957
# [torch.FloatTensor of size 1]
#
# 55
#  335.0583
# [torch.FloatTensor of size 1]
#
# 56
#  334.7232
# [torch.FloatTensor of size 1]
#
# 57
#  334.3897
# [torch.FloatTensor of size 1]
#
# 58
#  334.0581
# [torch.FloatTensor of size 1]
#
# 59
#  333.7288
# [torch.FloatTensor of size 1]
#
# 60
#  333.4013
# [torch.FloatTensor of size 1]
#
# 61
#  333.0756
# [torch.FloatTensor of size 1]
#
# 62
#  332.7519
# [torch.FloatTensor of size 1]
#
# 63
#  332.4298
# [torch.FloatTensor of size 1]
#
# 64
#  332.1100
# [torch.FloatTensor of size 1]
#
# 65
#  331.7917
# [torch.FloatTensor of size 1]
#
# 66
#  331.4752
# [torch.FloatTensor of size 1]
#
# 67
#  331.1605
# [torch.FloatTensor of size 1]
#
# 68
#  330.8477
# [torch.FloatTensor of size 1]
#
# 69
#  330.5367
# [torch.FloatTensor of size 1]
#
# 70
#  330.2273
# [torch.FloatTensor of size 1]
#
# 71
#  329.9199
# [torch.FloatTensor of size 1]
#
# 72
#  329.6137
# [torch.FloatTensor of size 1]
#
# 73
#  329.3097
# [torch.FloatTensor of size 1]
#
# 74
#  329.0070
# [torch.FloatTensor of size 1]
#
# 75
#  328.7061
# [torch.FloatTensor of size 1]
#
# 76
#  328.4067
# [torch.FloatTensor of size 1]
#
# 77
#  328.1092
# [torch.FloatTensor of size 1]
#
# 78
#  327.8130
# [torch.FloatTensor of size 1]
#
# 79
#  327.5185
# [torch.FloatTensor of size 1]
#
# 80
#  327.2255
# [torch.FloatTensor of size 1]
#
# 81
#  326.9343
# [torch.FloatTensor of size 1]
#
# 82
#  326.6447
# [torch.FloatTensor of size 1]
#
# 83
#  326.3564
# [torch.FloatTensor of size 1]
#
# 84
#  326.0699
# [torch.FloatTensor of size 1]
#
# 85
#  325.7845
# [torch.FloatTensor of size 1]
#
# 86
#  325.5007
# [torch.FloatTensor of size 1]
#
# 87
#  325.2184
# [torch.FloatTensor of size 1]
#
# 88
#  324.9376
# [torch.FloatTensor of size 1]
#
# 89
#  324.6583
# [torch.FloatTensor of size 1]
#
# 90
#  324.3805
# [torch.FloatTensor of size 1]
#
# 91
#  324.1039
# [torch.FloatTensor of size 1]
#
# 92
#  323.8289
# [torch.FloatTensor of size 1]
#
# 93
#  323.5551
# [torch.FloatTensor of size 1]
#
# 94
#  323.2827
# [torch.FloatTensor of size 1]
#
# 95
#  323.0117
# [torch.FloatTensor of size 1]
#
# 96
#  322.7422
# [torch.FloatTensor of size 1]
#
# 97
#  322.4738
# [torch.FloatTensor of size 1]
#
# 98
#  322.2068
# [torch.FloatTensor of size 1]
#
# 99
#  321.9412
# [torch.FloatTensor of size 1]
#
# 100
#  321.6769
# [torch.FloatTensor of size 1]
#
# 101
#  321.4139
# [torch.FloatTensor of size 1]
#
# 102
#  321.1521
# [torch.FloatTensor of size 1]
#
# 103
#  320.8916
# [torch.FloatTensor of size 1]
#
# 104
#  320.6323
# [torch.FloatTensor of size 1]
#
# 105
#  320.3743
# [torch.FloatTensor of size 1]
#
# 106
#  320.1176
# [torch.FloatTensor of size 1]
#
# 107
#  319.8622
# [torch.FloatTensor of size 1]
#
# 108
#  319.6080
# [torch.FloatTensor of size 1]
#
# 109
#  319.3549
# [torch.FloatTensor of size 1]
#
# 110
#  319.1028
# [torch.FloatTensor of size 1]
#
# 111
#  318.8524
# [torch.FloatTensor of size 1]
#
# 112
#  318.6026
# [torch.FloatTensor of size 1]
#
# 113
#  318.3543
# [torch.FloatTensor of size 1]
#
# 114
#  318.1071
# [torch.FloatTensor of size 1]
#
# 115
#  317.8609
# [torch.FloatTensor of size 1]
#
# 116
#  317.6159
# [torch.FloatTensor of size 1]
#
# 117
#  317.3722
# [torch.FloatTensor of size 1]
#
# 118
#  317.1294
# [torch.FloatTensor of size 1]
#
# 119
#  316.8875
# [torch.FloatTensor of size 1]
#
# 120
#  316.6472
# [torch.FloatTensor of size 1]
#
# 121
#  316.4078
# [torch.FloatTensor of size 1]
#
# 122
#  316.1694
# [torch.FloatTensor of size 1]
#
# 123
#  315.9321
# [torch.FloatTensor of size 1]
#
# 124
#  315.6956
# [torch.FloatTensor of size 1]
#
# 125
#  315.4604
# [torch.FloatTensor of size 1]
#
# 126
#  315.2264
# [torch.FloatTensor of size 1]
#
# 127
#  314.9931
# [torch.FloatTensor of size 1]
#
# 128
#  314.7611
# [torch.FloatTensor of size 1]
#
# 129
#  314.5299
# [torch.FloatTensor of size 1]
#
# 130
#  314.2999
# [torch.FloatTensor of size 1]
#
# 131
#  314.0708
# [torch.FloatTensor of size 1]
#
# 132
#  313.8426
# [torch.FloatTensor of size 1]
#
# 133
#  313.6155
# [torch.FloatTensor of size 1]
#
# 134
#  313.3895
# [torch.FloatTensor of size 1]
#
# 135
#  313.1642
# [torch.FloatTensor of size 1]
#
# 136
#  312.9400
# [torch.FloatTensor of size 1]
#
# 137
#  312.7168
# [torch.FloatTensor of size 1]
#
# 138
#  312.4944
# [torch.FloatTensor of size 1]
#
# 139
#  312.2729
# [torch.FloatTensor of size 1]
#
# 140
#  312.0525
# [torch.FloatTensor of size 1]
#
# 141
#  311.8329
# [torch.FloatTensor of size 1]
#
# 142
#  311.6143
# [torch.FloatTensor of size 1]
#
# 143
#  311.3965
# [torch.FloatTensor of size 1]
#
# 144
#  311.1796
# [torch.FloatTensor of size 1]
#
# 145
#  310.9638
# [torch.FloatTensor of size 1]
#
# 146
#  310.7487
# [torch.FloatTensor of size 1]
#
# 147
#  310.5347
# [torch.FloatTensor of size 1]
#
# 148
#  310.3212
# [torch.FloatTensor of size 1]
#
# 149
#  310.1089
# [torch.FloatTensor of size 1]
#
# 150
#  309.8972
# [torch.FloatTensor of size 1]
#
# 151
#  309.6866
# [torch.FloatTensor of size 1]
#
# 152
#  309.4767
# [torch.FloatTensor of size 1]
#
# 153
#  309.2676
# [torch.FloatTensor of size 1]
#
# 154
#  309.0594
# [torch.FloatTensor of size 1]
#
# 155
#  308.8521
# [torch.FloatTensor of size 1]
#
# 156
#  308.6455
# [torch.FloatTensor of size 1]
#
# 157
#  308.4400
# [torch.FloatTensor of size 1]
#
# 158
#  308.2349
# [torch.FloatTensor of size 1]
#
# 159
#  308.0309
# [torch.FloatTensor of size 1]
#
# 160
#  307.8275
# [torch.FloatTensor of size 1]
#
# 161
#  307.6250
# [torch.FloatTensor of size 1]
#
# 162
#  307.4234
# [torch.FloatTensor of size 1]
#
# 163
#  307.2225
# [torch.FloatTensor of size 1]
#
# 164
#  307.0225
# [torch.FloatTensor of size 1]
#
# 165
#  306.8230
# [torch.FloatTensor of size 1]
#
# 166
#  306.6243
# [torch.FloatTensor of size 1]
#
# 167
#  306.4265
# [torch.FloatTensor of size 1]
#
# 168
#  306.2294
# [torch.FloatTensor of size 1]
#
# 169
#  306.0331
# [torch.FloatTensor of size 1]
#
# 170
#  305.8374
# [torch.FloatTensor of size 1]
#
# 171
#  305.6426
# [torch.FloatTensor of size 1]
#
# 172
#  305.4485
# [torch.FloatTensor of size 1]
#
# 173
#  305.2551
# [torch.FloatTensor of size 1]
#
# 174
#  305.0625
# [torch.FloatTensor of size 1]
#
# 175
#  304.8707
# [torch.FloatTensor of size 1]
#
# 176
#  304.6795
# [torch.FloatTensor of size 1]
#
# 177
#  304.4890
# [torch.FloatTensor of size 1]
#
# 178
#  304.2990
# [torch.FloatTensor of size 1]
#
# 179
#  304.1099
# [torch.FloatTensor of size 1]
#
# 180
#  303.9216
# [torch.FloatTensor of size 1]
# 181
#  303.7340
# [torch.FloatTensor of size 1]
#
# 182
#  303.5471
# [torch.FloatTensor of size 1]
#
# 183
#  303.3607
# [torch.FloatTensor of size 1]
#
# 184
#  303.1752
# [torch.FloatTensor of size 1]
#
# 185
#  302.9904
# [torch.FloatTensor of size 1]
#
# 186
#  302.8058
# [torch.FloatTensor of size 1]
#
# 187
#  302.6225
# [torch.FloatTensor of size 1]
#
# 188
#  302.4394
# [torch.FloatTensor of size 1]
#
# 189
#  302.2571
# [torch.FloatTensor of size 1]
#
# 190
#  302.0756
# [torch.FloatTensor of size 1]
#
# 191
#  301.8947
# [torch.FloatTensor of size 1]
#
# 192
#  301.7142
# [torch.FloatTensor of size 1]
#
# 193
#  301.5347
# [torch.FloatTensor of size 1]
#
# 194
#  301.3556
# [torch.FloatTensor of size 1]
#
# 195
#  301.1772
# [torch.FloatTensor of size 1]
#
# 196
#  300.9995
# [torch.FloatTensor of size 1]
#
# 197
#  300.8224
# [torch.FloatTensor of size 1]
#
# 198
#  300.6458
# [torch.FloatTensor of size 1]
#
# 199
#  300.4700
# [torch.FloatTensor of size 1]
#
# 200
#  300.2949
# [torch.FloatTensor of size 1]
#
# 201
#  300.1203
# [torch.FloatTensor of size 1]
#
# 202
#  299.9463
# [torch.FloatTensor of size 1]
#
# 203
#  299.7729
# [torch.FloatTensor of size 1]
#
# 204
#  299.6000
# [torch.FloatTensor of size 1]
#
# 205
#  299.4277
# [torch.FloatTensor of size 1]
#
# 206
#  299.2563
# [torch.FloatTensor of size 1]
#
# 207
#  299.0853
# [torch.FloatTensor of size 1]
#
# 208
#  298.9150
# [torch.FloatTensor of size 1]
#
# 209
#  298.7451
# [torch.FloatTensor of size 1]
#
# 210
#  298.5758
# [torch.FloatTensor of size 1]
#
# 211
#  298.4072
# [torch.FloatTensor of size 1]
#
# 212
#  298.2392
# [torch.FloatTensor of size 1]
#
# 213
#  298.0717
# [torch.FloatTensor of size 1]
#
# 214
#  297.9049
# [torch.FloatTensor of size 1]
#
# 215
#  297.7385
# [torch.FloatTensor of size 1]
#
# 216
#  297.5726
# [torch.FloatTensor of size 1]
#
# 217
#  297.4074
# [torch.FloatTensor of size 1]
#
# 218
#  297.2428
# [torch.FloatTensor of size 1]
#
# 219
#  297.0788
# [torch.FloatTensor of size 1]
#
# 220
#  296.9152
# [torch.FloatTensor of size 1]
#
# 221
#  296.7522
# [torch.FloatTensor of size 1]
#
# 222
#  296.5898
# [torch.FloatTensor of size 1]
#
# 223
#  296.4277
# [torch.FloatTensor of size 1]
#
# 224
#  296.2664
# [torch.FloatTensor of size 1]
#
# 225
#  296.1054
# [torch.FloatTensor of size 1]
#
# 226
#  295.9454
# [torch.FloatTensor of size 1]
#
# 227
#  295.7856
# [torch.FloatTensor of size 1]
#
# 228
#  295.6265
# [torch.FloatTensor of size 1]
#
# 229
#  295.4678
# [torch.FloatTensor of size 1]
#
# 230
#  295.3097
# [torch.FloatTensor of size 1]
#
# 231
#  295.1521
# [torch.FloatTensor of size 1]
#
# 232
#  294.9949
# [torch.FloatTensor of size 1]
#
# 233
#  294.8385
# [torch.FloatTensor of size 1]
#
# 234
#  294.6825
# [torch.FloatTensor of size 1]
#
# 235
#  294.5268
# [torch.FloatTensor of size 1]
#
# 236
#  294.3717
# [torch.FloatTensor of size 1]
#
# 237
#  294.2171
# [torch.FloatTensor of size 1]
#
# 238
#  294.0632
# [torch.FloatTensor of size 1]
#
# 239
#  293.9097
# [torch.FloatTensor of size 1]
#
# 240
#  293.7567
# [torch.FloatTensor of size 1]
#
# 241
#  293.6040
# [torch.FloatTensor of size 1]
#
# 242
#  293.4523
# [torch.FloatTensor of size 1]
#
# 243
#  293.3007
# [torch.FloatTensor of size 1]
#
# 244
#  293.1497
# [torch.FloatTensor of size 1]
#
# 245
#  292.9991
# [torch.FloatTensor of size 1]
#
# 246
#  292.8491
# [torch.FloatTensor of size 1]
#
# 247
#  292.6994
# [torch.FloatTensor of size 1]
#
# 248
#  292.5504
# [torch.FloatTensor of size 1]
#
# 249
#  292.4018
# [torch.FloatTensor of size 1]
#
# 250
#  292.2537
# [torch.FloatTensor of size 1]
#
# 251
#  292.1061
# [torch.FloatTensor of size 1]
#
# 252
#  291.9590
# [torch.FloatTensor of size 1]
#
# 253
#  291.8122
# [torch.FloatTensor of size 1]
#
# 254
#  291.6659
# [torch.FloatTensor of size 1]
#
# 255
#  291.5203
# [torch.FloatTensor of size 1]
#
# 256
#  291.3749
# [torch.FloatTensor of size 1]
#
# 257
#  291.2301
# [torch.FloatTensor of size 1]
#
# 258
#  291.0857
# [torch.FloatTensor of size 1]
#
# 259
#  290.9417
# [torch.FloatTensor of size 1]
#
# 260
#  290.7982
# [torch.FloatTensor of size 1]
#
# 261
#  290.6553
# [torch.FloatTensor of size 1]
#
# 262
#  290.5128
# [torch.FloatTensor of size 1]
#
# 263
#  290.3707
# [torch.FloatTensor of size 1]
#
# 264
#  290.2290
# [torch.FloatTensor of size 1]
#
# 265
#  290.0878
# [torch.FloatTensor of size 1]
#
# 266
#  289.9471
# [torch.FloatTensor of size 1]
#
# 267
#  289.8066
# [torch.FloatTensor of size 1]
#
# 268
#  289.6670
# [torch.FloatTensor of size 1]
#
# 269
#  289.5275
# [torch.FloatTensor of size 1]
#
# 270
#  289.3884
# [torch.FloatTensor of size 1]
#
# 271
#  289.2499
# [torch.FloatTensor of size 1]
#
# 272
#  289.1118
# [torch.FloatTensor of size 1]
#
# 273
#  288.9739
# [torch.FloatTensor of size 1]
#
# 274
#  288.8368
# [torch.FloatTensor of size 1]
#
# 275
#  288.6999
# [torch.FloatTensor of size 1]
#
# 276
#  288.5634
# [torch.FloatTensor of size 1]
#
# 277
#  288.4274
# [torch.FloatTensor of size 1]
#
# 278
#  288.2918
# [torch.FloatTensor of size 1]
#
# 279
#  288.1567
# [torch.FloatTensor of size 1]
#
# 280
#  288.0220
# [torch.FloatTensor of size 1]
#
# 281
#  287.8877
# [torch.FloatTensor of size 1]
#
# 282
#  287.7537
# [torch.FloatTensor of size 1]
#
# 283
#  287.6202
# [torch.FloatTensor of size 1]
#
# 284
#  287.4873
# [torch.FloatTensor of size 1]
#
# 285
#  287.3546
# [torch.FloatTensor of size 1]
#
# 286
#  287.2222
# [torch.FloatTensor of size 1]
#
# 287
#  287.0905
# [torch.FloatTensor of size 1]
#
# 288
#  286.9589
# [torch.FloatTensor of size 1]
#
# 289
#  286.8279
# [torch.FloatTensor of size 1]
#
# 290
#  286.6972
# [torch.FloatTensor of size 1]
#
# 291
#  286.5670
# [torch.FloatTensor of size 1]
#
# 292
#  286.4374
# [torch.FloatTensor of size 1]
#
# 293
#  286.3077
# [torch.FloatTensor of size 1]
#
# 294
#  286.1785
# [torch.FloatTensor of size 1]
#
# 295
#  286.0501
# [torch.FloatTensor of size 1]
#
# 296
#  285.9218
# [torch.FloatTensor of size 1]
#
# 297
#  285.7941
# [torch.FloatTensor of size 1]
#
# 298
#  285.6663
# [torch.FloatTensor of size 1]
#
# 299
#  285.5392
# [torch.FloatTensor of size 1]
#
# 300
#  285.4124
# [torch.FloatTensor of size 1]
#
# 301
#  285.2861
# [torch.FloatTensor of size 1]
#
# 302
#  285.1602
# [torch.FloatTensor of size 1]
#
# 303
#  285.0345
# [torch.FloatTensor of size 1]
#
# 304
#  284.9095
# [torch.FloatTensor of size 1]
#
# 305
#  284.7845
# [torch.FloatTensor of size 1]
#
# 306
#  284.6601
# [torch.FloatTensor of size 1]
#
# 307
#  284.5361
# [torch.FloatTensor of size 1]
#
# 308
#  284.4122
# [torch.FloatTensor of size 1]
#
# 309
#  284.2890
# [torch.FloatTensor of size 1]
#
# 310
#  284.1662
# [torch.FloatTensor of size 1]
#
# 311
#  284.0435
# [torch.FloatTensor of size 1]
#
# 312
#  283.9213
# [torch.FloatTensor of size 1]
#
# 313
#  283.7995
# [torch.FloatTensor of size 1]
#
# 314
#  283.6778
# [torch.FloatTensor of size 1]
#
# 315
#  283.5566
# [torch.FloatTensor of size 1]
#
# 316
#  283.4361
# [torch.FloatTensor of size 1]
#
# 317
#  283.3157
# [torch.FloatTensor of size 1]
#
# 318
#  283.1954
# [torch.FloatTensor of size 1]
#
# 319
#  283.0758
# [torch.FloatTensor of size 1]
#
# 320
#  282.9565
# [torch.FloatTensor of size 1]
#
# 321
#  282.8374
# [torch.FloatTensor of size 1]
#
# 322
#  282.7188
# [torch.FloatTensor of size 1]
#
# 323
#  282.6006
# [torch.FloatTensor of size 1]
#
# 324
#  282.4827
# [torch.FloatTensor of size 1]
#
# 325
#  282.3648
# [torch.FloatTensor of size 1]
#
# 326
#  282.2478
# [torch.FloatTensor of size 1]
#
# 327
#  282.1309
# [torch.FloatTensor of size 1]
#
# 328
#  282.0142
# [torch.FloatTensor of size 1]
#
# 329
#  281.8983
# [torch.FloatTensor of size 1]
#
# 330
#  281.7822
# [torch.FloatTensor of size 1]
#
# 331
#  281.6667
# [torch.FloatTensor of size 1]
#
# 332
#  281.5514
# [torch.FloatTensor of size 1]
#
# 333
#  281.4366
# [torch.FloatTensor of size 1]
#
# 334
#  281.3221
# [torch.FloatTensor of size 1]
#
# 335
#  281.2081
# [torch.FloatTensor of size 1]
#
# 336
#  281.0942
# [torch.FloatTensor of size 1]
#
# 337
#  280.9806
# [torch.FloatTensor of size 1]
#
# 338
#  280.8675
# [torch.FloatTensor of size 1]
#
# 339
#  280.7546
# [torch.FloatTensor of size 1]
#
# 340
#  280.6422
# [torch.FloatTensor of size 1]
#
# 341
#  280.5299
# [torch.FloatTensor of size 1]
#
# 342
#  280.4181
# [torch.FloatTensor of size 1]
#
# 343
#  280.3065
# [torch.FloatTensor of size 1]
#
# 344
#  280.1954
# [torch.FloatTensor of size 1]
#
# 345
#  280.0843
# [torch.FloatTensor of size 1]
#
# 346
#  279.9738
# [torch.FloatTensor of size 1]
#
# 347
#  279.8636
# [torch.FloatTensor of size 1]
#
# 348
#  279.7536
# [torch.FloatTensor of size 1]
#
# 349
#  279.6441
# [torch.FloatTensor of size 1]
#
# 350
#  279.5348
# [torch.FloatTensor of size 1]
#
# 351
#  279.4258
# [torch.FloatTensor of size 1]
#
# 352
#  279.3171
# [torch.FloatTensor of size 1]
#
# 353
#  279.2088
# [torch.FloatTensor of size 1]
#
# 354
#  279.1008
# [torch.FloatTensor of size 1]
#
# 355
#  278.9930
# [torch.FloatTensor of size 1]
#
# 356
#  278.8857
# [torch.FloatTensor of size 1]
#
# 357
#  278.7786
# [torch.FloatTensor of size 1]
#
# 358
#  278.6718
# [torch.FloatTensor of size 1]
#
# 359
#  278.5651
# [torch.FloatTensor of size 1]
# 360
#  278.4590
# [torch.FloatTensor of size 1]
#
# 361
#  278.3530
# [torch.FloatTensor of size 1]
#
# 362
#  278.2476
# [torch.FloatTensor of size 1]
#
# 363
#  278.1425
# [torch.FloatTensor of size 1]
#
# 364
#  278.0373
# [torch.FloatTensor of size 1]
#
# 365
#  277.9326
# [torch.FloatTensor of size 1]
#
# 366
#  277.8283
# [torch.FloatTensor of size 1]
#
# 367
#  277.7242
# [torch.FloatTensor of size 1]
#
# 368
#  277.6204
# [torch.FloatTensor of size 1]
#
# 369
#  277.5170
# [torch.FloatTensor of size 1]
#
# 370
#  277.4138
# [torch.FloatTensor of size 1]
#
# 371
#  277.3110
# [torch.FloatTensor of size 1]
#
# 372
#  277.2082
# [torch.FloatTensor of size 1]
#
# 373
#  277.1059
# [torch.FloatTensor of size 1]
#
# 374
#  277.0040
# [torch.FloatTensor of size 1]
#
# 375
#  276.9023
# [torch.FloatTensor of size 1]
#
# 376
#  276.8008
# [torch.FloatTensor of size 1]
#
# 377
#  276.6997
# [torch.FloatTensor of size 1]
#
# 378
#  276.5988
# [torch.FloatTensor of size 1]
#
# 379
#  276.4982
# [torch.FloatTensor of size 1]
#
# 380
#  276.3979
# [torch.FloatTensor of size 1]
#
# 381
#  276.2979
# [torch.FloatTensor of size 1]
#
# 382
#  276.1981
# [torch.FloatTensor of size 1]
#
# 383
#  276.0987
# [torch.FloatTensor of size 1]
#
# 384
#  275.9995
# [torch.FloatTensor of size 1]
#
# 385
#  275.9005
# [torch.FloatTensor of size 1]
#
# 386
#  275.8020
# [torch.FloatTensor of size 1]
#
# 387
#  275.7037
# [torch.FloatTensor of size 1]
#
# 388
#  275.6057
# [torch.FloatTensor of size 1]
#
# 389
#  275.5078
# [torch.FloatTensor of size 1]
#
# 390
#  275.4104
# [torch.FloatTensor of size 1]
#
# 391
#  275.3131
# [torch.FloatTensor of size 1]
#
# 392
#  275.2162
# [torch.FloatTensor of size 1]
#
# 393
#  275.1194
# [torch.FloatTensor of size 1]
#
# 394
#  275.0230
# [torch.FloatTensor of size 1]
#
# 395
#  274.9268
# [torch.FloatTensor of size 1]
#
# 396
#  274.8311
# [torch.FloatTensor of size 1]
#
# 397
#  274.7354
# [torch.FloatTensor of size 1]
#
# 398
#  274.6401
# [torch.FloatTensor of size 1]
#
# 399
#  274.5450
# [torch.FloatTensor of size 1]
#
# 400
#  274.4500
# [torch.FloatTensor of size 1]
#
# 401
#  274.3555
# [torch.FloatTensor of size 1]
#
# 402
#  274.2612
# [torch.FloatTensor of size 1]
#
# 403
#  274.1671
# [torch.FloatTensor of size 1]
#
# 404
#  274.0734
# [torch.FloatTensor of size 1]
#
# 405
#  273.9798
# [torch.FloatTensor of size 1]
#
# 406
#  273.8867
# [torch.FloatTensor of size 1]
#
# 407
#  273.7937
# [torch.FloatTensor of size 1]
#
# 408
#  273.7010
# [torch.FloatTensor of size 1]
#
# 409
#  273.6085
# [torch.FloatTensor of size 1]
#
# 410
#  273.5162
# [torch.FloatTensor of size 1]
#
# 411
#  273.4243
# [torch.FloatTensor of size 1]
#
# 412
#  273.3325
# [torch.FloatTensor of size 1]
#
# 413
#  273.2412
# [torch.FloatTensor of size 1]
#
# 414
#  273.1499
# [torch.FloatTensor of size 1]
#
# 415
#  273.0589
# [torch.FloatTensor of size 1]
#
# 416
#  272.9682
# [torch.FloatTensor of size 1]
#
# 417
#  272.8777
# [torch.FloatTensor of size 1]
#
# 418
#  272.7876
# [torch.FloatTensor of size 1]
#
# 419
#  272.6977
# [torch.FloatTensor of size 1]
#
# 420
#  272.6080
# [torch.FloatTensor of size 1]
#
# 421
#  272.5184
# [torch.FloatTensor of size 1]
#
# 422
#  272.4292
# [torch.FloatTensor of size 1]
#
# 423
#  272.3402
# [torch.FloatTensor of size 1]
#
# 424
#  272.2514
# [torch.FloatTensor of size 1]
#
# 425
#  272.1630
# [torch.FloatTensor of size 1]
#
# 426
#  272.0747
# [torch.FloatTensor of size 1]
#
# 427
#  271.9867
# [torch.FloatTensor of size 1]
#
# 428
#  271.8989
# [torch.FloatTensor of size 1]
#
# 429
#  271.8115
# [torch.FloatTensor of size 1]
#
# 430
#  271.7243
# [torch.FloatTensor of size 1]
#
# 431
#  271.6372
# [torch.FloatTensor of size 1]
#
# 432
#  271.5503
# [torch.FloatTensor of size 1]
#
# 433
#  271.4637
# [torch.FloatTensor of size 1]
#
# 434
#  271.3775
# [torch.FloatTensor of size 1]
#
# 435
#  271.2913
# [torch.FloatTensor of size 1]
#
# 436
#  271.2055
# [torch.FloatTensor of size 1]
#
# 437
#  271.1199
# [torch.FloatTensor of size 1]
#
# 438
#  271.0343
# [torch.FloatTensor of size 1]
#
# 439
#  270.9493
# [torch.FloatTensor of size 1]
#
# 440
#  270.8642
# [torch.FloatTensor of size 1]
#
# 441
#  270.7795
# [torch.FloatTensor of size 1]
#
# 442
#  270.6950
# [torch.FloatTensor of size 1]
#
# 443
#  270.6108
# [torch.FloatTensor of size 1]
#
# 444
#  270.5267
# [torch.FloatTensor of size 1]
#
# 445
#  270.4430
# [torch.FloatTensor of size 1]
#
# 446
#  270.3595
# [torch.FloatTensor of size 1]
#
# 447
#  270.2761
# [torch.FloatTensor of size 1]
#
# 448
#  270.1928
# [torch.FloatTensor of size 1]
#
# 449
#  270.1100
# [torch.FloatTensor of size 1]
#
# 450
#  270.0273
# [torch.FloatTensor of size 1]
#
# 451
#  269.9449
# [torch.FloatTensor of size 1]
#
# 452
#  269.8626
# [torch.FloatTensor of size 1]
#
# 453
#  269.7806
# [torch.FloatTensor of size 1]
#
# 454
#  269.6989
# [torch.FloatTensor of size 1]
#
# 455
#  269.6172
# [torch.FloatTensor of size 1]
#
# 456
#  269.5359
# [torch.FloatTensor of size 1]
#
# 457
#  269.4547
# [torch.FloatTensor of size 1]
#
# 458
#  269.3740
# [torch.FloatTensor of size 1]
#
# 459
#  269.2932
# [torch.FloatTensor of size 1]
#
# 460
#  269.2126
# [torch.FloatTensor of size 1]
#
# 461
#  269.1323
# [torch.FloatTensor of size 1]
#
# 462
#  269.0522
# [torch.FloatTensor of size 1]
#
# 463
#  268.9724
# [torch.FloatTensor of size 1]
#
# 464
#  268.8929
# [torch.FloatTensor of size 1]
#
# 465
#  268.8134
# [torch.FloatTensor of size 1]
#
# 466
#  268.7342
# [torch.FloatTensor of size 1]
#
# 467
#  268.6552
# [torch.FloatTensor of size 1]
#
# 468
#  268.5764
# [torch.FloatTensor of size 1]
#
# 469
#  268.4978
# [torch.FloatTensor of size 1]
#
# 470
#  268.4194
# [torch.FloatTensor of size 1]
#
# 471
#  268.3413
# [torch.FloatTensor of size 1]
#
# 472
#  268.2633
# [torch.FloatTensor of size 1]
#
# 473
#  268.1857
# [torch.FloatTensor of size 1]
#
# 474
#  268.1081
# [torch.FloatTensor of size 1]
#
# 475
#  268.0308
# [torch.FloatTensor of size 1]
#
# 476
#  267.9536
# [torch.FloatTensor of size 1]
#
# 477
#  267.8766
# [torch.FloatTensor of size 1]
#
# 478
#  267.8000
# [torch.FloatTensor of size 1]
#
# 479
#  267.7234
# [torch.FloatTensor of size 1]
#
# 480
#  267.6471
# [torch.FloatTensor of size 1]
#
# 481
#  267.5711
# [torch.FloatTensor of size 1]
#
# 482
#  267.4951
# [torch.FloatTensor of size 1]
#
# 483
#  267.4193
# [torch.FloatTensor of size 1]
#
# 484
#  267.3437
# [torch.FloatTensor of size 1]
#
# 485
#  267.2688
# [torch.FloatTensor of size 1]
#
# 486
#  267.1934
# [torch.FloatTensor of size 1]
#
# 487
#  267.1185
# [torch.FloatTensor of size 1]
#
# 488
#  267.0436
# [torch.FloatTensor of size 1]
#
# 489
#  266.9691
# [torch.FloatTensor of size 1]
#
# 490
#  266.8948
# [torch.FloatTensor of size 1]
#
# 491
#  266.8206
# [torch.FloatTensor of size 1]
#
# 492
#  266.7467
# [torch.FloatTensor of size 1]
#
# 493
#  266.6729
# [torch.FloatTensor of size 1]
#
# 494
#  266.5995
# [torch.FloatTensor of size 1]
#
# 495
#  266.5261
# [torch.FloatTensor of size 1]
#
# 496
#  266.4529
# [torch.FloatTensor of size 1]
#
# 497
#  266.3798
# [torch.FloatTensor of size 1]
#
# 498
#  266.3070
# [torch.FloatTensor of size 1]
#
# 499
#  266.2345
# [torch.FloatTensor of size 1]

# %%
# Обратно в Numpy для отрисовки
X = X.data.numpy()
y = y.data.numpy()

# %%
# Отрисовочна магия, снова взято из:
# http://cs231n.github.io/neural-networks-case-study/#linear

h = 0.02
x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1

xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                     np.arange(y_min, y_max, h))
grid_tensor = torch.FloatTensor(np.c_[xx.ravel(), yy.ravel()])

Z = neuron(torch.autograd.Variable(grid_tensor))
Z = Z.data.numpy()
Z = np.argmax(Z, axis=1)
Z = Z.reshape(xx.shape)

plt.figure(figsize=(10, 8))

plt.contourf(xx, yy, Z, cmap=plt.cm.rainbow, alpha=0.3)
plt.scatter(X[:, 0], X[:, 1], c=y, s=40, cmap=plt.cm.rainbow)

plt.xlim(xx.min(), xx.max())
plt.ylim(yy.min(), yy.max())

plt.title('Игрушка дьявола', fontsize=15)
plt.xlabel('$x$', fontsize=14)
plt.ylabel('$y$', fontsize=14)
plt.show();

# %% [markdown]
# ---

# %% [markdown]
# ### Задача 2

# %% [markdown]
# Меняя все известные Вам способы улучшения нейросети, постарайтесь добиться лучшего качества здесь. (**архитектуру менять нельзя**, мы же хотим добиться победы одним нейроном (слоем)).

# %%
# Ваш код здесь (можно (и нужно) создавать несколько ячеек)

# %% [markdown]
# ---

# %% [markdown]
# <h3 style="text-align: center;"><b>Полезные ссылки</b></h3>

# %% [markdown]
# 1). *Примеры написания нейросетей на PyTorch (офийиальные туториалы) (на английском): https://pytorch.org/tutorials/beginner/pytorch_with_examples.html#examples
# https://pytorch.org/tutorials/beginner/blitz/cifar10_tutorial.html*
#
# 2). ***Один из самых подробных и полных курсов по deep learning на данный момент - это курс Стэнфордского Университета (он вообще сейчас один из лидеров в области ИИ, его выпускники работают в Google, Facebook, Amazon, Microsoft, в стартапах в Кремниевой долине):  http://cs231n.github.io/***
#
# 3). Практически исчерпывающая информация по основам нейросетей (из cs231n) (на английском):
#
# http://cs231n.github.io/neural-networks-1/,
# http://cs231n.github.io/neural-networks-2/,
# http://cs231n.github.io/neural-networks-3/,
# http://cs231n.github.io/neural-networks-case-study/#linear
#
# 4). *Хорошие статьи по основам нейросетей (на английском):  http://neuralnetworksanddeeplearning.com/chap1.html*
#
# 5). *Наглядная демонстрация того, как обучаются нейросети:  https://cs.stanford.edu/people/karpathy/convnetjs/*
